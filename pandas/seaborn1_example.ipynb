# %%
# !pip install seaborn
# Out:
# ...
#   Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Basic plotting with seaborn    
tips = sns.load_dataset('tips')##inbuild dataset only in seaborn
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
##categorical plot
##barplot
sns.boxplot(x='sex', y='total_bill',data=tips)
sns
# Out:
# <module 'seaborn' from 'c:\\Users\\DELL\\OneDrive\\Desktop\\Data Analyst course\\Python\\New folder\\.venv\\Lib\\site-packages\\seaborn\\__init__.py'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# box plot
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.violinplot(x='day', y= 'total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(tips['total_bill'], bins=20, kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## kde plot
sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
##pair plot
sns.pairplot(tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ##pair plot
# ----> 2 sns.pairplot(tips)
#
# NameError: name 'sns' is not defined

# %%
## heatmap
corr = tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
plt.figure(figsize=(10,5))
sns.barplot(x= 'Product', y= 'Value', data=df, estimator=sum)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)
 
data = {
    'Age': np.random.randint(20,45, size=15),
    'Salary': np.random.randint(10000, 40000, size=15),
    'department': np.random.choice(['Hr','Tl','Manager','Qc'], size=15)
    
}

df= pd.DataFrame(data)
plt.figure(figsize=(10,6))
plt.title("My team")
sns.boxplot(x='department', y= 'Salary', data=df)
sns
# Out:
# <module 'seaborn' from 'c:\\Users\\DELL\\OneDrive\\Desktop\\Data Analyst course\\Python\\New folder\\.venv\\Lib\\site-packages\\seaborn\\__init__.py'>

# %%
salary_sum = df.groupby('department')['Salary'].sum()

plt.pie(salary_sum, labels=salary_sum.index, autopct='%1.1f%%', startangle=90)
plt.title('Total Salary Contribution by Department')
plt.show()
