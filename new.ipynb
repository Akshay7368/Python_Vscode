# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'Oracle in XE', 'SQL Server Native Client RDA 11.0', 'ODBC Driver 17 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)', 'ODBC Driver 18 for SQL Server']

# %%
import pyodbc
import pandas as pd

# Use Windows Authentication
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 18 for SQL Server};'
    'SERVER=DESKTOP-M7FKHP9\\MSSQLSERVER01;'
    'DATABASE=TestDB;'  # replace with your DB name
    'Trusted_Connection=yes;'
    'TrustServerCertificate=yes;'
)

# Example query
df = pd.read_sql("SELECT * FROM Employees", conn)
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20328\1550391678.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM Employees", conn)
#     ID     Name Department  Salary
# 0    1   Akshay         IT   60000
# 1    2     Ravi    Finance   55000
# 2    3    Meena         IT   65000
# 3    4     John         HR   50000
# 4    5     Jack         IT   15000
# 5    6      Abi    Finance   26000
# 6    7     Bala         TL   45000
# 7    8  Charles         TL   32000
# 8    9    David         IT   61000
# 9   10    Frank    Finance   46000
# 10  11     Zara         HR   23000

# %%
# !pip install SQLAlchemy
# Out:
# ...
#   Using cached greenlet-3.2.3-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# ...
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 6.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.3 MB/s  0:00:00
# Using cached greenlet-3.2.3-cp313-cp313-win_amd64.whl (297 kB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# ...
#
#    ---------------------------------------- 0/3 [typing-extensions]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
# ...

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
df = pd.read_sql("SELECT Department, AVG(Salary) AS Avg_Salary FROM Employees GROUP BY Department", conn)
sns.barplot(x="Department", y="Avg_Salary", data=df)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20328\2582311002.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT Department, AVG(Salary) AS Avg_Salary FROM Employees GROUP BY Department", conn)
# <Axes: xlabel='Department', ylabel='Avg_Salary'>

# %%
import pandas as pd
from sqlalchemy import create_engine
import pyodbc

# %%
conn_str = (
    "mssql+pyodbc://DESKTOP-M7FKHP9\\MSSQLSERVER01/hr?driver=ODBC+Driver+17+for+SQL+Server"
)
engine = create_engine(conn_str)

# %%
import sqlite3

# %%
conn = sqlite3.connect('empflask.db')

# %%
cursor = conn.cursor()

# %%
conn_str = ("mssql+pyodbc://DESKTOP-M7FKHP9\\MSSQLSERVER01/hr?driver=ODBC+Driver+17+for+SQL+Server")
engine = create_engine(conn_str)

# %%
df = pd.read_sql("select * from employees",engine)
df
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER   HIRE_DATE  \
# 0          100.0     Steven      King     SKING  515.123.4567  1987-06-17
# 1          101.0      Neena   Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2          102.0        Lex   De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3          103.0  Alexander    Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4          104.0      Bruce     Ernst    BERNST  590.423.4568  1987-06-21
# ..           ...        ...       ...       ...           ...         ...
# 102        202.0        Pat       Fay      PFAY  603.123.6666  1987-09-27
# 103        203.0      Susan    Mavris   SMAVRIS  515.123.7777  1987-09-28
# 104        204.0    Hermann      Baer     HBAER  515.123.8888  1987-09-29
# 105        205.0    Shelley   Higgins  SHIGGINS  515.123.8080  1987-09-30
# 106        206.0    William     Gietz    WGIETZ  515.123.8181  1987-10-01
#
#          JOB_ID   SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
df = pd.read_sql('select TOp 5 First_name,Last_name,salary from employees where salary < 5000',engine)
sns.lineplot(x = 'First_name', y = 'salary',data=df)
sns.barplot(x = 'First_name', y = 'salary',data=df)
sns
# Out:
# <module 'seaborn' from 'c:\\Users\\DELL\\OneDrive\\Desktop\\Data Analyst course\\Python\\New folder\\.venv\\Lib\\site-packages\\seaborn\\__init__.py'>
